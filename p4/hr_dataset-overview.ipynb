# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("/Users/dwihadyan/Downloads/theleadio/ds-exploration/p4/data/HR_dataset.csv")
df
# Out:
#                   names  satisfaction_level  last_evaluation  number_project  \
# 0        Jessica Stroud                0.38             0.53               2
# 1          Daryl Fields                0.80             0.86               5
# 2        Daisy Anderson                0.11             0.88               7
# 3      Joseph Fernandez                0.72             0.87               5
# 4         Herbert Moore                0.37             0.52               2
# ...                 ...                 ...              ...             ...
# 14995        Roger King                0.37             0.48               2
# 14996         Ora Lyles                0.37             0.53               2
# 14997   Steven Freedman                0.11             0.96               6
# 14998  Randall Williams                0.37             0.52               2
# 14999    Bessie Coleman                0.82             0.91               5
#
# ...

# %%
df.describe()
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# count        15000.000000     15000.000000    15000.000000
# mean             0.612847         0.716115        3.803133
# std              0.248628         0.171171        1.232590
# min              0.090000         0.360000        2.000000
# 25%              0.440000         0.560000        3.000000
# 50%              0.640000         0.720000        4.000000
# 75%              0.820000         0.870000        5.000000
# max              1.000000         1.000000        7.000000
#
#        average_monthly_hours  exp_in_company  work_accident          left  \
# count           15000.000000    15000.000000   15000.000000  15000.000000
# mean              201.052400        3.498333       0.144600      0.238133
# std                49.942074        1.460139       0.351709      0.425955
# min                96.000000        2.000000       0.000000      0.000000
# ...
